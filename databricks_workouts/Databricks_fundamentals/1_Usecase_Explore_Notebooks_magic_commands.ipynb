# %% [markdown]
# #Welcome to Inceptez Technologies
# Let's go and learn Big Data  _Mr.Paartha_
# ![](https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png)

# %%
 # %sql
 create volume if not exists workspace.default.usage_metrics

# %%
# %py
import requests
url ="https://public.tableau.com/app/sample-data/mobile_os_usage.csv"
csv_data = requests.get(url).text
# Write data to volume
dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv", csv_data, overwrite=True)

# %%
# %py
df1 = spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv", header=True)
display(df1)

# %%
 # %run "/Workspace/Users/paarthasarathy1999@gmail.com/databricks-code-Repo/databricks_workouts/Databricks_fundamentals/4_child_nb_dataload"

# %%
# %fs
ls /Volumes/workspace/default/usage_metrics/

# %%
# %fs
head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
# %python
df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",header=True)

# %%
df2 = df2.withColumnRenamed(
    "Mobile Operating System", "Mobile_Operating_System"
).withColumnRenamed(
    "Percent of Usage", "Percent_of_Usage"
)
df2.write.saveAsTable("mobile_os_usage")

# %%
df_result = spark.sql("SELECT * FROM default.mobile_os_usage")

df_result.show(10)

# %%
def to_upper(text):
    return text.upper()

# %%
pip install pandas

# %%
import pandas
pandas.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")

# %%
# %sh
echo "Magic commands tasks completed"
